# %% [markdown]
# ## Machine Learning

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data PreProcessing
# * Data Cleaning
# * Data Integration
# * Data Transformation
# * Data Reduction
# * Data Discretization

# %%
df=pd.read_csv('Sales.csv')

# %%
df
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate        ShipMode  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1             2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2             3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID        ProductID         Category  SubCategory      Sales  \
# ...

# %%
df.describe(include="all")
# Out:
#           OrderLine         OrderID OrderDate    ShipDate        ShipMode  \
# count   9994.000000            9994      9994        9994            9994
# unique          NaN            5009      1237        1334               4
# top             NaN  CA-2017-100111  9/5/2016  12/16/2015  Standard Class
# freq            NaN              14        38          35            5968
# mean    4997.500000             NaN       NaN         NaN             NaN
# std     2885.163629             NaN       NaN         NaN             NaN
# min        1.000000             NaN       NaN         NaN             NaN
# 25%     2499.250000             NaN       NaN         NaN             NaN
# 50%     4997.500000             NaN       NaN         NaN             NaN
# 75%     7495.750000             NaN       NaN         NaN             NaN
# max     9994.000000             NaN       NaN         NaN             NaN
#
#        CustomerID        ProductID         Category SubCategory     Sales  \
# ...

# %%
# in data Cleaning first we need to drop duplicate entries
df.drop_duplicates()
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate        ShipMode  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1             2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2             3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID        ProductID         Category  SubCategory      Sales  \
# ...

# %%
#for remove column
df.drop(columns="ShipMode")
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate CustomerID  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016   CG-12520
# 1             2  CA-2016-152156   11/8/2016  11/11/2016   CG-12520
# 2             3  CA-2016-138688   6/12/2016   6/16/2016   DV-13045
# 3             4  US-2015-108966  10/11/2015  10/18/2015   SO-20335
# 4             5  US-2015-108966  10/11/2015  10/18/2015   SO-20335
# ...         ...             ...         ...         ...        ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014   TB-21400
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017   DB-13060
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017   DB-13060
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017   DB-13060
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017   CC-12220
#
#             ProductID         Category  SubCategory      Sales  Quantity  \
# 0     FUR-BO-10001798        Furniture    Bookcases  USD261.96         2
# ...

# %%
df
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate        ShipMode  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1             2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2             3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID        ProductID         Category  SubCategory      Sales  \
# ...

# %%
#strp method
# df["ShipMode"].str.strip()
# df["ShipMode"].str.lstrip("S")
df["ShipMode"].str.rstrip("s")
# Out:
# 0         Second Cla
# 1         Second Cla
# 2         Second Cla
# 3       Standard Cla
# 4       Standard Cla
#             ...
# 9989      Second Cla
# 9990    Standard Cla
# 9991    Standard Cla
# 9992    Standard Cla
# 9993      Second Cla
# Name: ShipMode, Length: 9994, dtype: object

# %%
df["ShipMode"].str.replace("Class","level")
# Out:
# 0         Second level
# 1         Second level
# 2         Second level
# 3       Standard level
# 4       Standard level
#              ...
# 9989      Second level
# 9990    Standard level
# 9991    Standard level
# 9992    Standard level
# 9993      Second level
# Name: ShipMode, Length: 9994, dtype: object

# %%
#spliting
df["ShipMode"].str.split(" ",1)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20004\2078380688.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df["ShipMode"].str.split(" ",1)
# 0         [Second, Class]
# 1         [Second, Class]
# 2         [Second, Class]
# 3       [Standard, Class]
# 4       [Standard, Class]
#               ...
# 9989      [Second, Class]
# 9990    [Standard, Class]
# 9991    [Standard, Class]
# 9992    [Standard, Class]
# 9993      [Second, Class]
# Name: ShipMode, Length: 9994, dtype: object

# %%
df["ShipMode"].str.split(" ",1,expand=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20004\344973320.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df["ShipMode"].str.split(" ",1,expand=True)
#              0      1
# 0       Second  Class
# 1       Second  Class
# 2       Second  Class
# 3     Standard  Class
# 4     Standard  Class
# ...        ...    ...
# 9989    Second  Class
# 9990  Standard  Class
# 9991  Standard  Class
# 9992  Standard  Class
# 9993    Second  Class
#
# [9994 rows x 2 columns]

# %%
df[["ShipMode1","ShipMode2"]]=df["ShipMode"].str.split(" ",1,expand=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20004\2269038958.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[["ShipMode1","ShipMode2"]]=df["ShipMode"].str.split(" ",1,expand=True)

# %%
df
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate        ShipMode  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1             2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2             3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID        ProductID         Category  SubCategory      Sales  \
# ...

# %%
for x in df.index:
    if df.iloc[x,'column']=="values":
        df.drop(x,inplace=True)

df

# %%
df.describe()
# Out:
#          OrderLine     Quantity     Discount       Profit
# count  9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000     3.789574     0.156203    28.656973
# std    2885.163629     2.225110     0.206452   234.260203
# min       1.000000     1.000000     0.000000 -6599.980000
# 25%    2499.250000     2.000000     0.000000     1.730000
# 50%    4997.500000     3.000000     0.200000     8.665000
# 75%    7495.750000     5.000000     0.200000    29.360000
# max    9994.000000    14.000000     0.800000  8399.980000

# %%
df
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate        ShipMode  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1             2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2             3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID        ProductID         Category  SubCategory      Sales  \
# ...

# %%
dfr=df.describe(include='object')

# %%
df1=pd.read_csv('Customers.csv')

# %%
df1
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 0      CG-12520        Claire Gute     Consumer   67  United States
# 1      DV-13045    Darrin Van Huff    Corporate   31  United States
# 2      SO-20335     Sean O'Donnell     Consumer   65  United States
# 3      BH-11710    Brosina Hoffman     Consumer   20  United States
# 4      AA-10480       Andrew Allen     Consumer   50  United States
# ..          ...                ...          ...  ...            ...
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City           State  Postal Code   Region
# 0            Henderson        Kentucky        42420    South
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'OrderLine'}>,
#         <Axes: title={'center': 'Quantity'}>],
#        [<Axes: title={'center': 'Discount'}>,
#         <Axes: title={'center': 'Profit'}>]], dtype=object)

# %%
dfr.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dfr.plot.bar()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1159, in PlotAccessor.bar(self, x, y, **kwargs)
#    1071 @Appender(
#    1072     """
#    1073     See Also
#    (...)
#    1148 @Appender(_bar_or_line_doc)
#    1149 def bar(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1150     """
#    1151     Vertical bar plot.
#    1152
#    (...)
#    1157     other axis represents a measured value.
#    1158     """
# -> 1159     return self(kind="bar", x=x, y=y, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.columns
# Out:
# Index(['OrderLine', 'OrderID', 'OrderDate', 'ShipDate', 'ShipMode',
#        'CustomerID', 'ProductID', 'Category', 'SubCategory', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df["ShipDate"].value_counts().to_frame()
# Out:
#             ShipDate
# 12/16/2015        35
# 9/26/2017         34
# 12/6/2017         32
# 11/21/2017        32
# 9/6/2017          30
# ...              ...
# 3/4/2014           1
# 2/11/2017          1
# 8/7/2016           1
# 4/8/2017           1
# 6/18/2015          1
#
# [1334 rows x 1 columns]

# %%
plt.bar('hi',20)
# Out:
# <BarContainer object of 1 artists>

# %%
plt.bar()

# %%
test=df.Category.value_counts().to_frame()

# %%
plt.bar(test.index,test.items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plt.bar(test.index,test.items)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2412, in bar(x, height, width, bottom, align, data, **kwargs)
#    2408 @_copy_docstring_and_deprecators(Axes.bar)
#    2409 def bar(
#    2410         x, height, width=0.8, bottom=None, *, align='center',
#    2411         data=None, **kwargs):
# -> 2412     return gca().bar(
#    2413         x, height, width=width, bottom=bottom, align=align,
#    2414         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
# ...

# %%
test.items
# Out:
# <bound method DataFrame.items of                  Category
# Office Supplies      6026
# Furniture            2121
# Technology           1847>

# %%
test
# Out:
#                  Category
# Office Supplies      6026
# Furniture            2121
# Technology           1847

# %%
test.Category
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
test.plot.bar()
# Out:
# <Axes: >

# %%
test.plot.pie()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 test.plot.pie()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1611, in PlotAccessor.pie(self, **kwargs)
#    1560 """
#    1561 Generate a pie plot.
#    1562
#    (...)
#    1604     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1605 """
#    1606 if (
#    1607     isinstance(self._parent, ABCDataFrame)
#    1608     and kwargs.get("y", None) is None
#    1609     and not kwargs.get("subplots", False)
#    1610 ):
# -> 1611     raise ValueError("pie requires either y column or 'subplots=True'")
#    1612 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
test.plot.pie??
# Out:
# Signature: test.plot.pie(**kwargs) -> 'PlotAccessor'
# Source:
#     def pie(self, **kwargs) -> PlotAccessor:
#         """
#         Generate a pie plot.
#
#         A pie plot is a proportional representation of the numerical data in a
#         column. This function wraps :meth:`matplotlib.pyplot.pie` for the
#         specified column. If no column reference is passed and
#         ``subplots=True`` a pie plot is drawn for each numerical column
#         independently.
#
#         Parameters
#         ----------
#         y : int or label, optional
#             Label or position of the column to plot.
#             If not provided, ``subplots=True`` argument must be passed.
#         **kwargs
#             Keyword arguments to pass on to :meth:`DataFrame.plot`.
#
#         Returns
#         -------
#         matplotlib.axes.Axes or np.ndarray of them
#             A NumPy array is returned when `subplots` is True.
#
#         See Also
#         --------
# ...

# %%
df.Category.value_counts(normalize=True)
# Out:
# Office Supplies    0.602962
# Furniture          0.212227
# Technology         0.184811
# Name: Category, dtype: float64

# %%
df.Category.value_counts(normalize=True)*100
# Out:
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: Category, dtype: float64

# %%
test["Percentage"]=df.Category.value_counts(normalize=True)*100

# %%
test
# Out:
#                  Category  Percentage
# Office Supplies      6026   60.296178
# Furniture            2121   21.222734
# Technology           1847   18.481089

# %%
test1=test.drop('Category',axis=1)

# %%
test1
# Out:
#                  Percentage
# Office Supplies   60.296178
# Furniture         21.222734
# Technology        18.481089

# %%
test1.plot.pie()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 test1.plot.pie()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1611, in PlotAccessor.pie(self, **kwargs)
#    1560 """
#    1561 Generate a pie plot.
#    1562
#    (...)
#    1604     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1605 """
#    1606 if (
#    1607     isinstance(self._parent, ABCDataFrame)
#    1608     and kwargs.get("y", None) is None
#    1609     and not kwargs.get("subplots", False)
#    1610 ):
# -> 1611     raise ValueError("pie requires either y column or 'subplots=True'")
#    1612 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
test1.plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 test1.plot(kind='pie')
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:951, in PlotAccessor.__call__(self, *args, **kwargs)
#     949 if isinstance(data, ABCDataFrame):
#     950     if y is None and kwargs.get("subplots") is False:
# --> 951         raise ValueError(
#     952             f"{kind} requires either y column or 'subplots=True'"
#     953         )
#     954     elif y is not None:
#     955         if is_integer(y) and not data.columns.holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
k=test1.Percentage

# %%
k
# Out:
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: Percentage, dtype: float64

# %%
k.plot.pie()
# Out:
# <Axes: ylabel='Percentage'>

# %%
k.plot(kind='pie')
# Out:
# <Axes: ylabel='Percentage'>

# %%
df
# Out:
#       OrderLine         OrderID   OrderDate    ShipDate        ShipMode  \
# 0             1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1             2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2             3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993       9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      CustomerID        ProductID         Category  SubCategory      Sales  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.columns
# Out:
# Index(['OrderLine', 'OrderID', 'OrderDate', 'ShipDate', 'ShipMode',
#        'CustomerID', 'ProductID', 'Category', 'SubCategory', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.Profit
# Out:
# 0        41.91
# 1       219.58
# 2         6.87
# 3      -383.03
# 4         2.52
#          ...
# 9989      4.10
# 9990     15.63
# 9991     19.39
# 9992     13.32
# 9993     72.95
# Name: Profit, Length: 9994, dtype: float64

# %%
df.Profit.describe()
# Out:
# count    9994.000000
# mean       28.656973
# std       234.260203
# min     -6599.980000
# 25%         1.730000
# 50%         8.665000
# 75%        29.360000
# max      8399.980000
# Name: Profit, dtype: float64

# %%
df.Profit.to_frame().boxplot()
# Out:
# <Axes: >

# %%
df.Profit.to_frame().hist()
# Out:
# array([[<Axes: title={'center': 'Profit'}>]], dtype=object)

# %%
plt.scatter(df.Quantity,df.Discount)

# %%
test_1=df.SubCategory.value_counts().to_frame()

# %%
test_1
# Out:
#              SubCategory
# Binders             1523
# Paper               1370
# Furnishings          957
# Phones               889
# Storage              846
# Art                  796
# Accessories          775
# Chairs               617
# Appliances           466
# Labels               364
# Tables               319
# Envelopes            254
# Bookcases            228
# Fasteners            217
# Supplies             190
# Machines             115
# Copiers               68

# %%
test_1.plot.bar()
# Out:
# <Axes: >

# %%
test.plot.bar()
test_1.plot.bar()
# Out:
# <Axes: >
