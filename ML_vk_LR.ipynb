# %%
import pandas as pd

# %%
df=pd.read_csv('VK100.csv',index_col=[0])

# %%
df.head(5)
# Out:
#        Format  Inning Position  Score  Balls  Strike Rate      Against  \
# Number
# 1         ODI       2        4    107    114    93.859649    Sri Lanka
# 2         ODI       2        3    102     95   107.368421   Bangladesh
# 3         ODI       2        3    118    121    97.520661    Australia
# 4         ODI       1        3    105    104   100.961539  New Zealand
# 5         ODI       1        4    100     83   120.481928   Bangladesh
#
#            Venue Host Nation      Series  Year  Team Total  Wickets lost  \
# Number
# 1        Kolkata       India   Bilateral  2009         316             3
# 2         Mirpur  Bangladesh  Tri-Series  2010         249             4
# 3          Vizag       India   Bilateral  2010         292             5
# 4       Guwahati       India   Bilateral  2010         276            10
# 5         Mirpur  Bangladesh   World Cup  2011         370             4
#
#        Not Out MOTM  Win Captain
# Number
# 1           No   No  Yes      No
# ...

# %%
df=df.drop(["MOTM","Win","Captain","Series"],axis=1)

# %%
df_odi=df[df.Format=='ODI']

# %%
df.describe()
# Out:
#           Inning       Score       Balls  Strike Rate         Year  \
# count  87.000000   87.000000   87.000000    87.000000    87.000000
# mean    1.643678  129.367816  146.482759   103.405971  2016.275862
# std     0.664324   34.474836   75.912260    38.835304     3.668501
# min     1.000000  100.000000   50.000000    34.915254  2009.000000
# 25%     1.000000  107.000000   96.500000    75.665266  2013.500000
# 50%     2.000000  117.000000  119.000000    97.520661  2016.000000
# 75%     2.000000  138.500000  192.000000   121.093677  2018.000000
# max     4.000000  254.000000  366.000000   226.000000  2023.000000
#
#        Team Total  Wickets lost
# count   87.000000     87.000000
# mean   336.482759      6.057471
# std    115.286081      2.833998
# min    166.000000      1.000000
# 25%    269.000000      4.000000
# 50%    311.000000      6.000000
# 75%    366.000000      9.000000
# max    687.000000     10.000000

# %%
df.columns
# Out:
# Index(['Format', 'Inning', 'Position', 'Score', 'Balls', 'Strike Rate',
#        'Against', 'Venue', 'Host Nation', 'Year', 'Team Total', 'Wickets lost',
#        'Not Out'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
e=LabelEncoder()

# %%
df.Format=e.fit_transform(df.Format)

# %%
df.Position=e.fit_transform(df.Position)

# %%
df.Venue=e.fit_transform(df.Venue)

# %%
df["Host Nation"]=e.fit_transform(df["Host Nation"])

# %%
df.Against=e.fit_transform(df.Against)

# %%
df
# Out:
#         Format  Inning  Position  Score  Balls  Strike Rate  Against  Venue  \
# Number
# 1            0       2         1    107    114    93.859649       12     27
# 2            0       2         0    102     95   107.368421        2     29
# 3            0       2         0    118    121    97.520661        1     43
# 4            0       1         0    105    104   100.961539        8     17
# 5            0       1         1    100     83   120.481928        2     29
# ...        ...     ...       ...    ...    ...          ...      ...    ...
# 83           3       1         1    121    206    58.737864       14     37
# 84           0       1         0    122     94   129.787234        9     10
# 85           0       2         0    103     97   106.185567        2     38
# 86           0       1         0    101    121    83.471074       11     27
# 87           0       1         0    117    112   104.464286        8     31
#
# ...

# %%
df["Not Out"]=e.fit_transform(df["Not Out"])

# %%
df.describe()
# Out:
#           Format     Inning   Position       Score       Balls  Strike Rate  \
# count  87.000000  87.000000  87.000000   87.000000   87.000000    87.000000
# mean    1.103448   1.643678   0.839080  129.367816  146.482759   103.405971
# std     1.389617   0.664324   1.180004   34.474836   75.912260    38.835304
# min     0.000000   1.000000   0.000000  100.000000   50.000000    34.915254
# 25%     0.000000   1.000000   0.000000  107.000000   96.500000    75.665266
# 50%     0.000000   2.000000   1.000000  117.000000  119.000000    97.520661
# 75%     3.000000   2.000000   1.000000  138.500000  192.000000   121.093677
# max     3.000000   4.000000   4.000000  254.000000  366.000000   226.000000
#
#          Against      Venue  Host Nation         Year  Team Total  \
# count  87.000000  87.000000    87.000000    87.000000   87.000000
# mean    7.505747  22.298851     3.310345  2016.275862  336.482759
# std     4.999706  13.757125     2.174430     3.668501  115.286081
# ...

# %%
df.corr()
# Out:
#                 Format    Inning  Position     Score     Balls  Strike Rate  \
# Format        1.000000  0.267119  0.407380  0.405751  0.760981    -0.561805
# Inning        0.267119  1.000000 -0.029496 -0.130786  0.068011    -0.233388
# Position      0.407380 -0.029496  1.000000 -0.085708 -0.021060     0.317738
# Score         0.405751 -0.130786 -0.085708  1.000000  0.727473    -0.262605
# Balls         0.760981  0.068011 -0.021060  0.727473  1.000000    -0.758499
# Strike Rate  -0.561805 -0.233388  0.317738 -0.262605 -0.758499     1.000000
# Against      -0.190045 -0.158666 -0.185110  0.069878 -0.091734     0.006544
# Venue        -0.031440  0.000336 -0.229798  0.114040  0.095804    -0.132664
# Host Nation  -0.072320 -0.147947 -0.080010 -0.036441 -0.092777     0.068951
# Year          0.053642 -0.216846  0.072155  0.115586  0.014297     0.123493
# Team Total    0.511679 -0.180981 -0.136012  0.703676  0.734062    -0.450889
# ...

# %%
x=df.drop("Team Total",axis=1)

# %%
y=df["Team Total"]

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size = 0.20)

# %%
from sklearn.model_selection import train_test_split
